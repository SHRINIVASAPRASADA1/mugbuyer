# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv("MagBuy.csv")

# %%
dataset.head(6)
# Out:
#    Obs No.  Buy  Income  Is Female  Is Married  Has College  Is Professional  \
# 0        1    0   24000          1           0            1                1
# 1        2    1   75000          1           1            1                1
# 2        3    0   46000          1           1            0                0
# 3        4    1   70000          0           1            0                1
# 4        5    0   43000          1           0            0                0
# 5        6    0   24000          1           1            0                0
#
#    Is Retired  Unemployed  Residence Length  Dual Income  Minors  Own  House  \
# 0           0           0                26            0       0    0      1
# 1           0           0                15            1       0    1      1
# 2           0           0                36            1       1    1      1
# 3           0           0                55            0       0    1      1
# ...

# %%
dataset.isna().sum()
# Out:
# Obs No.             0
# Buy                 0
# Income              0
# Is Female           0
# Is Married          0
# Has College         0
# Is Professional     0
# Is Retired          0
# Unemployed          0
# Residence Length    0
# Dual Income         0
# Minors              0
# Own                 0
# House               0
# White               0
# English             0
# Prev Child Mag      0
# Prev Parent Mag     0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Obs No.           673 non-null    int64
#  1   Buy               673 non-null    int64
#  2   Income            673 non-null    int64
#  3   Is Female         673 non-null    int64
#  4   Is Married        673 non-null    int64
#  5   Has College       673 non-null    int64
#  6   Is Professional   673 non-null    int64
#  7   Is Retired        673 non-null    int64
#  8   Unemployed        673 non-null    int64
#  9   Residence Length  673 non-null    int64
#  10  Dual Income       673 non-null    int64
#  11  Minors            673 non-null    int64
#  12  Own               673 non-null    int64
#  13  House             673 non-null    int64
#  14  White             673 non-null    int64
#  15  English           673 non-null    int64
# ...

# %%
sbn.barplot(data=dataset,x="Income",y="Is Female")
# Out:
# <Axes: xlabel='Income', ylabel='Is Female'>

# %%
sbn.histplot(data=dataset,x="Income",y="Residence Length")
# Out:
# <Axes: xlabel='Income', ylabel='Residence Length'>

# %%
sbn.scatterplot(data=dataset,x="Income",y="Buy")
# Out:
# <Axes: xlabel='Income', ylabel='Buy'>

# %%
sbn.heatmap(dataset.corr())
# Out:
# <Axes: >

# %%
plt.pie(list(dataset["Is Female"].value_counts()),dataset["Is Female"].unique(),autopct='%1.1f%%')
plt.legend(title='Categories', loc='best')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Its just a index i think 
sbn.lineplot(dataset["Obs No."])
# Out:
# <Axes: ylabel='Obs No.'>

# %%
label = dataset['Buy']
features = dataset.drop("Buy",axis=1)


features = features.drop("Obs No.",axis=1)

# %%
model = DecisionTreeClassifier()

# %%
xtrain,xtest, ytrain , ytest = train_test_split(features,label)

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(xtest)

# %%
accuracy_score(ytest,pred)
# Out:
# 0.8875739644970414

# %%
model.score(xtest,ytest)
# Out:
# 0.8875739644970414

# %%
ytest.mean()
# Out:
# 0.1952662721893491

# %%
pred.mean()
# Out:
# 0.1893491124260355

# %%
out = model.predict(xtest.head(1))
out
# Out:
# array([0])

# %%
ytest.head(1)
# Out:
# 406    0
# Name: Buy, dtype: int64
